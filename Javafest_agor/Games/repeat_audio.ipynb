# %%
pip install groq
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# "Transcription(text=' \u09b9\u09b2\u09cb \u0985\u09ae\u09c7\u0987 \u09ad\u09be\u09b2\u09cb \u0986\u099b\u09c7', task='transcribe', language='Bengali', duration=5.71, words=[{'word': '\u09b9\u09b2\u09cb', 'start': 0, 'end': 2.18}, {'word': '\u0985\u09ae\u09c7\u0987', 'start': 2.18, 'end': 2.82}, {'word': '\u09ad\u09be\u09b2\u09cb', 'start': 2.82, 'end': 3.2}, {'word': '\u0986\u099b\u09c7', 'start': 3.2, 'end': 3.72}], segments=[{'id': 0, 'seek': 0, 'start': 0, 'end': 5.72, 'text': ' \u09b9\u09b2\u09cb \u0985\u09ae\u09c7\u0987 \u09ad\u09be\u09b2\u09cb \u0986\u099b\u09c7', 'tokens': [50365, 220, 29045, 117, 29045, 110, 156, 100, 233, 220, 29045, 227, 29045, 106, 156, 100, 229, 29045, 229, 220, 29045, 255, 29045, 122, 29045, 110, 156, 100, 233, 220, 29045, 228, 29045, 249, 156, 100, 229, 50651], 'temperature': 0, 'avg_logprob': -0.22972144, 'compression_ratio': 0.9782609, 'no_speech_prob': 0.35429716}], x_groq={'id': 'req_01k31d8ez0farrzvf5b5xhn5w7'})"
# হলো অমেই ভালো আছে
